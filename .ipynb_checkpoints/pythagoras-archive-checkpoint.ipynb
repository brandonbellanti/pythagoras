# %% [markdown]
# # pythagoras
#
# Welcome to _pythagoras_. For more information about the project, visit the [project website](http://web.simmons.edu/~bellanti/pythagoras) or the Github repo.
#
# ---
#
# # Brandenburg Concerto No. 2 in F Major, BWV 1047
# J.S. Bach

# %% [markdown]
# ### Load libraries and settings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from lxml import etree
import re
from collections import Counter
# %matplotlib inline

# %% [markdown]
# ### Parse the MusicXML file

# %%
# xml_filepath = "./scores/xml/JSB_BWV1047_1.xml"
# xml_filepath = "./scores/xml/JSB_BWV1047_2.xml"
xml_filepath = "./scores/xml/JSB_BWV1047_3.xml"

# %%
tree = etree.parse(xml_filepath)
root = tree.getroot()

# %% [markdown]
# ### Get information about the work

# %%
print('\nINSTRUMENTATION:\n')

parts = []

for e in root.xpath('//score-part'):
    part = e.xpath('./@id')[0]
    parts.append(part)
    instr = e.xpath('.//instrument-name')[0].text
    print("\t%s (%s)" % (instr,part))
# Out:
# INSTRUMENTATION:
#
# 	Trumpet (P1)
# 	Recorder (P2)
# 	Oboe (P3)
# 	Violin (P4)
# 	Violin (P5)
# 	Violin (P6)
# 	Viola (P7)
# 	Violon Cello (P8)
# 	Contrabass (P9)

# %%
print('\nKEY & TIME\n')

attrib_list = root.xpath("//part[@id='P1']/measure[@number='1']/attributes/*")

key_dict = {
    '-7':'Cb major (Ab minor)',
    '-6':'Gb major (Eb minor)',
    '-5':'Db major (Bb minor)',
    '-4':'Ab major (F minor)',
    '-3':'Eb major (C minor)',
    '-2':'Bb major (G minor)',
    '-1':'F major (D minor)',
    '0':'C major (A minor)',
    '1':'G major (E minor)',
    '2':'D major (B minor)',
    '3':'A major (F# minor)',
    '4':'E major (C# minor)',
    '5':'B major (G# minor)',
    '6':'F# major (D# minor)',
    '7':'C# major (A# minor)'
}

for e in attrib_list:
    if e.tag == 'key':
        accidentals = e.xpath('./fifths')[0].text
        mode = e.xpath('./mode')[0].text
        key = key_dict[accidentals]
        print("\tKey signature:\t", key)
    if e.tag == 'time':
        beats = e.xpath('./beats')[0].text
        val = e.xpath('./beat-type')[0].text
        time = "%s/%s" % (beats,val)
        print("\tTime signature:\t",time)
# Out:
# KEY & TIME
#
# 	Key signature:	 F major (D minor)
# 	Time signature:	 2/4

# %% [markdown]
# ### Build a dataframe with notes

# %%
notes = []

for e in root.xpath('//note'):
    
    part = e.xpath('../..//@id')[0]
    
    measure = e.xpath('..//@number')[0]
    
    dotted = True if 'dot' in [child.tag for child in e] else False

    rest = True if 'rest' in [child.tag for child in e] else False
    
    duration_list = e.xpath('.//duration/text()')
    duration = duration_list[0] if len(duration_list)>0 else ''
    
    typ_list = e.xpath('.//type/text()')
    typ = typ_list[0] if len(typ_list)>0 else ''

    
    step_list = e.xpath('.//step/text()')
    step = step_list[0] if len(step_list)>0 else ''
    
    alter_list = e.xpath('.//alter/text()')
    alter = alter_list[0] if len(alter_list)>0 else ''
    if alter == '0':
        accidental = ''
    elif alter == '-1':
        accidental = 'b'
    elif alter == '1':
        accidental = '#'
    elif alter == '-2':
        accidental = 'bb'
    elif alter == '2':
        accidental = '##'
    else:
        accidental = ''

    
    pitch = step + accidental
    
    octave_list = e.xpath('.//octave/text()')
    octave = octave_list[0] if len(step_list)>0 else ''
    
    notes.append((part,measure,pitch,step,alter,octave,duration,typ,dotted,rest))

# %%
df = pd.DataFrame(notes,columns=['part','measure','pitch','step','alter','octave','duration','type','dotted','rest'])
print(df)
# Out:
#      part measure pitch step alter octave duration     type  dotted   rest
# 0      P1       1     F    F            5        2   eighth   False  False
# 1      P1       1     C    C            6        2   eighth   False  False
# 2      P1       1     C    C            6        2   eighth   False  False
# 3      P1       1    Bb    B    -1      5        1     16th   False  False
# 4      P1       1     C    C            6        1     16th   False  False
# 5      P1       2     D    D            6        2   eighth   False  False
# 6      P1       2     C    C            6        1     16th   False  False
# 7      P1       2    Bb    B    -1      5        1     16th   False  False
# 8      P1       2     C    C            6        2   eighth   False  False
# 9      P1       2     F    F            6        2   eighth   False  False
# 10     P1       3     C    C            6        2   eighth   False  False
# 11     P1       3     A    A            5        1     16th   False  False
# 12     P1       3    Bb    B    -1      5        1     16th   False  False
# 13     P1       3     C    C            6        2   eighth   False  False
# 14     P1       3    Bb    B    -1      5        1     16th   False  False
# 15     P1       3     C    C            6        1     16th   False  False
# 16     P1       4     D    D            6        2   eighth   False  False
# 17     P1       4     C    C            6        1     16th   False  False
# 18     P1       4    Bb    B    -1      5        1     16th   False  False
# 19     P1       4     C    C            6        1     16th   False  False
# 20     P1       4    Bb    B    -1      5        1     16th   False  False
# 21     P1       4     A    A            5        1     16th   False  False
# 22     P1       4     C    C            6        1     16th   False  False
# 23     P1       5    Bb    B    -1      5        1     16th   False  False
# 24     P1       5     A    A            5        1     16th   False  False
# 25     P1       5     G    G            5        1     16th   False  False
# 26     P1       5    Bb    B    -1      5        1     16th   False  False
# 27     P1       5     A    A            5        1     16th   False  False
# 28     P1       5     G    G            5        1     16th   False  False
# 29     P1       5     F    F            5        1     16th   False  False
# ...   ...     ...   ...  ...   ...    ...      ...      ...     ...    ...
# 4294   P9     131     F    F            3        1     16th   False  False
# 4295   P9     131     D    D            3        1     16th   False  False
# 4296   P9     131    Eb    E    -1      3        1     16th   False  False
# 4297   P9     131     F    F            3        1     16th   False  False
# 4298   P9     132    Bb    B    -1      2        4  quarter   False  False
# 4299   P9     132                                2   eighth   False   True
# 4300   P9     132    Bb    B    -1      3        2   eighth   False  False
# 4301   P9     133    Bb    B    -1      3        2   eighth   False  False
# 4302   P9     133     C    C            4        1     16th   False  False
# 4303   P9     133    Bb    B    -1      3        1     16th   False  False
# 4304   P9     133     A    A            3        2   eighth   False  False
# 4305   P9     133    Bb    B    -1      3        1     16th   False  False
# 4306   P9     133     A    A            3        1     16th   False  False
# 4307   P9     134     G    G            3        2   eighth   False  False
# 4308   P9     134     A    A            3        1     16th   False  False
# 4309   P9     134     G    G            3        1     16th   False  False
# 4310   P9     134     F    F            3        2   eighth   False  False
# 4311   P9     134     A    A            2        2   eighth   False  False
# 4312   P9     135    Bb    B    -1      2        2   eighth   False  False
# 4313   P9     135     G    G            2        2   eighth   False  False
# 4314   P9     135     C    C            3        2   eighth   False  False
# 4315   P9     135     C    C            2        2   eighth   False  False
# 4316   P9     136     F    F            2        4  quarter   False  False
# 4317   P9     136     F    F            2        4  quarter   False  False
# 4318   P9     137     F    F            2        4  quarter   False  False
# 4319   P9     137     F    F            2        4  quarter   False  False
# 4320   P9     138     F    F            2        4  quarter   False  False
# 4321   P9     138     F    F            2        4  quarter   False  False
# 4322   P9     139     F    F            2        4  quarter   False  False
# 4323   P9     139     F    F            2        4  quarter   False  False
#
# [4324 rows x 10 columns]

# %% [markdown]
# ### Vizualizations

# %%
col = 'type'
df[df[col]!=''].groupby(col)[col].count().sort_values(ascending=False).plot.bar()
plt.ylabel('Count')
plt.xlabel('Note type')
plt.title('Note types')
# Out:
# Text(0.5,1,'Note types')

# %%
df = df.set_index('part',append=True)

# %%
pitch_df = df.groupby('pitch')['pitch'].count()
print(pitch_df)
# table = pd.pivot_table(df, values='pitch', index=[part],columns=['part'], aggfunc=np.unique)
# print(table)
# pd.pivot_table(df, columns='pitch', values='step').plot(subplots=True)
# print(table)
# Out:
# pitch
#       788
# A     468
# Ab     15
# B     130
# Bb    282
# C     547
# C#     66
# D     496
# D#      4
# Db      1
# E     362
# Eb     94
# F     541
# F#     13
# Fb      1
# G     516
# Name: pitch, dtype: int64

# %%
print('\nPITCH COUNTS BY PART\n')

col = 'pitch'
result = df[df[col]!=''].groupby(['part',col])[col].count()
result_df = result.to_frame().rename (columns={col:'count'}).reset_index()
p = len(parts)
if p%2 == 0:
    num_rows = int(p/2)
    fig, ax = plt.subplots(num_rows,2,figsize=(12,num_rows*4))
elif p%3 == 0:
    num_rows = int(p/3)
    fig, ax = plt.subplots(num_rows,3,figsize=(15,num_rows*3))
else:
    num_rows = p
    fig, ax = plt.subplots(num_rows,1,figsize=(10,num_rows))

result_df.pivot(index=col,columns='part',values='count').sort_values(by="P1",ascending=False).plot.bar(subplots=True, ax=ax,legend=False, sharex=False)

plt.tight_layout()
plt.show()
# Out:
# PITCH COUNTS BY PART

# %%
pitch_dict = {'A0':'1','G##0':'1','Bbb0':'1','A#0':'2','Bb0':'2','Cbb1':'2','B0':'3','Cb1':'3','A##0':'3','C1':'4','B#0':'4','Dbb1':'4','C#1':'5','Db1':'5','B##1':'5','D1':'6','C##1':'6','Dbb1':'6','D#1':'7','Eb1':'7','Fbb1':'7','E1':'8','Fb1':'8','D##1':'8','1':'8','F1':'9','E#1':'9','Gbb1':'9','F#1':'10','Gb1':'10','E##1':'10','G1':'11','F##1':'11','Abb1':'11','G#1
eb7':'79','Fbb7':'79','E7':'80','Fb7':'80','D##7':'80','7':'80','F7':'81','E#7':'81','Gbb7':'81','F#7':'82','Gb7':'82','E##7':'82','G7':'83','F##7':'83','Abb7':'83','G#7':'84','Ab7':'84','A7':'85','G##7':'85','Bbb7':'85','A#7':'86','Bb7':'86','Cbb8':'86','B7':'87','Cb8':'87','A##7':'87','C8':'88','B#7':'88','Dbb8':'88'}

# %% [markdown]
# ### Pitches
#
# Because this song is written in the key of F, the expected most common pitches are as follows:
#
# * **I chord**: F-A-C
# * **IV chord**: Bb-D-F
# * **V(7) chord**: C-E-G(-Bb)
# * **vi chord**: D-F-A
# * **ii chord**: G-Bb-D

# %%
col = 'pitch'
df[df[col]!=''].groupby(col)[col].count().sort_values(ascending=False).plot.bar(subplots=True)
plt.ylabel('Count')
plt.xlabel('Pitch')
plt.title('Pitches')
# Out:
# Text(0.5,1,'Pitches')

# %% [markdown]
# ## Match patterns
# Using the string generated from the dataframe series, match any reoccuring patterns longer than a given length.

# %%
steps = df['type'].to_string(index=False)
steps = re.sub(r'\n|\t| ','',steps)
print(steps)
# Out:
# ...

# %%
min_length = 8
min_occur = 2
pat = r'(?=(.{%d,})).*\1{%d,}' % (min_length, min_occur-1)

step_patterns = re.findall(pat,steps)

print(Counter(step_patterns))
# Out:
# Counter({'...': 1})

# %%
min_length = 5
min_occur = 8
pat = r'(?=(.{%d,})(?=.*\1){%d,})' % (min_length, min_occur-1)
step_patterns = re.findall(pat,steps)
print(Counter(step_patterns))
# Out:
# Counter({'CCCCCCC': 9, 'FEDCD': 5, 'DEDCD': 4, 'GFEDC': 4, 'CDECDE': 4, 'DECDE': 4, 'DCBAB': 4, 'CBAGF': 4, 'GFEDE': 4, 'DCBAGF': 3, 'FGFGAGFG': 3, 'DCBAG': 3, 'BAGFG': 3, 'BCDBCD': 3, 'CDBCD': 3, 'CDCBC': 3, 'CDEFG': 3, 'EDDCC': 3, 'DECDECDE': 3, 'ECDECDE': 3, 'ABAGA': 3, 'GFGAGFG': 3, 'FGAGFG': 3, 'GAGFG': 3, 'EFGEFG': 3, 'FGEFG': 3, 'GABGAB': 3, 'ABGAB': 3, 'CDEFDEF': 3, 'FEDEFGFEDE': 3, 'EDEFGFEDE': 3, 'DEFGFEDE': 3, 'EFGFEDE': 3, 'FGFEDE': 3, 'CDECD': 3, 'GFEGFEDFE': 3, 'FEGFEDFE': 3, 'EGFEDFE': 3, 'GFEDFE': 3, 'FEDFE': 3, 'FGFEF': 3, 'DEFDEF': 3, 'EFDEF': 3, 'GFEDCD': 3, 'FFFFFFFF': 3, 'FGABGABCABC': 2, 'DEDCBAGF': 2, 'EDCBAGF': 2, 'GABAB': 2, 'FGAGABAGAFGAFGAGABAGF': 2, 'GAGABAGAFGAFGAGABAGF': 2, 'AGABAGAFGAFGAGABAGF': 2, 'GABAGAFGAFGAGABAGF':